# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 현재경로 설정
# !cd "/content/drive/My Drive/Colab Notebooks/URP/kaist_pd_urp"

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/URP/kaist_pd_urp')

# %%
# !git clone https://github.com/sgrvinod/a-PyTorch-Tutorial-to-Object-Detection.git
# Out:
# Cloning into 'a-PyTorch-Tutorial-to-Object-Detection'...
# remote: Enumerating objects: 249, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 249 (delta 60), reused 57 (delta 57), pack-reused 181
# Receiving objects: 100% (249/249), 175.95 MiB | 71.16 MiB/s, done.
# Resolving deltas: 100% (118/118), done.

# %%
# !python utils.py

# %%
# !python create_data_lists.py
# Out:
# 시작2
# 시작8
# 100% 8730/8730 [50:14<00:00,  2.90it/s]
#
# TRAIN DATA) Files have been saved to /content/drive/MyDrive/kaist_output.
#
#
# There are 8730 training images containing a total of 26384 objects. Files have been saved to /content/drive/MyDrive/kaist_output.
#
# TEST DATA) START2
#
# TEST DATA) Files have been saved to /content/drive/MyDrive/kaist_output.

# %%
# !python datasets.py

# %%
# !python model.py

# %%
# !python train.py
# Out:
# Loaded checkpoint from epoch 25.
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# Epoch: [25][0/273]	Batch Time 55.081 (55.081)	Data Time 42.685 (42.685)	Loss 2.4798 (2.4798)
# Epoch: [25][200/273]	Batch Time 8.818 (5.199)	Data Time 8.295 (4.622)	Loss 2.5119 (2.5741)
# Epoch: [26][0/273]	Batch Time 5.106 (5.106)	Data Time 4.519 (4.519)	Loss 2.6204 (2.6204)
# Epoch: [26][200/273]	Batch Time 0.580 (1.111)	Data Time 0.010 (0.560)	Loss 2.1657 (2.5539)
# Epoch: [27][0/273]	Batch Time 4.538 (4.538)	Data Time 3.995 (3.995)	Loss 2.4822 (2.4822)
# Epoch: [27][200/273]	Batch Time 0.558 (1.096)	Data Time 0.001 (0.549)	Loss 2.3817 (2.5262)
# Epoch: [28][0/273]	Batch Time 4.341 (4.341)	Data Time 3.764 (3.764)	Loss 2.4231 (2.4231)
# Epoch: [28][200/273]	Batch Time 2.790 (1.120)	Data Time 2.251 (0.571)	Loss 2.6036 (2.5481)
# ...

# %%
# !python detect.py
# Out:
# Loaded checkpoint from epoch 80.
#
# 1it [00:04,  4.34s/it]/content/drive/MyDrive/Colab Notebooks/URP/kaist_pd_urp/model.py:503: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:27.)
#   image_boxes.append(class_decoded_locs[1 - suppress])
# /content/drive/MyDrive/Colab Notebooks/URP/kaist_pd_urp/model.py:505: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:27.)
#   image_scores.append(class_scores[1 - suppress])
# 2252it [24:11,  1.55it/s]

# %%
# !python Evaluation_official.py
# Out:
# loading annotations into memory...
# Done (t=1.02s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.22s).
# Accumulating evaluation results...
# DONE (t=0.00s).
#  Average Miss Rate  (MR) @ Reasonable         [ IoU=0.50      | height=[55:10000000000] | visibility=[none+partial_occ] ] = 29.34%
# Recall: 0.8299367533380183

# %%
# !python moving_image.py
# Out:
# Loaded checkpoint from epoch 80.
#
# 출력4
# 1it [00:01,  1.03s/it]/content/drive/MyDrive/Colab Notebooks/URP/kaist_pd_urp/model.py:503: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:27.)
#   image_boxes.append(class_decoded_locs[1 - suppress])
# /content/drive/MyDrive/Colab Notebooks/URP/kaist_pd_urp/model.py:505: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:27.)
#   image_scores.append(class_scores[1 - suppress])
# 2252it [00:58, 38.30it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'

# %%
# import os
# import json

# with open(os.path.join('/content/drive/MyDrive/kaist_output/TRAIN_objects.json'), 'r') as j:
#       nobjects = json.load(j)
# with open(os.path.join('/content/drive/MyDrive/kaist_output/TRAIN_nobjects.json'), 'r') as j:
#       objects = json.load(j)

# nobjects == objects
# Out:
# True

# %%
# !python
