# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 현재경로 설정
# !cd "/content/drive/My Drive/Colab Notebooks/URP/kaist_pd_urp"

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/URP/kaist_pd_urp')

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/URP/kaist_pd_urp

# %%
#!git clone https://github.com/sgrvinod/a-PyTorch-Tutorial-to-Object-Detection.git

# %%
# 바꾼것
# baseline을 도달하지 못한 원인이 learning rate가 너무 낮아 학습이 덜 된 것 때문이었다.
# 그렇다면 epoch를 상승한 상태에서 learning rate를 80에서 decay해주면 더 성능이 좋아지지 않을까?
# epoch 80 -> 100
# decay_lr_at 70 -> 80

# %%
# !python train.py
# Out:
# Loaded checkpoint from epoch 90.
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# Epoch: [90][0/273]	Batch Time 39.855 (39.855)	Data Time 26.571 (26.571)	Loss 2.4811 (2.4811)
# Epoch: [90][200/273]	Batch Time 0.517 (2.941)	Data Time 0.000 (2.357)	Loss 2.1554 (2.1875)
# Epoch: [91][0/273]	Batch Time 4.504 (4.504)	Data Time 3.921 (3.921)	Loss 2.1129 (2.1129)
# Epoch: [91][200/273]	Batch Time 1.792 (1.151)	Data Time 1.231 (0.601)	Loss 2.0836 (2.1507)
# Epoch: [92][0/273]	Batch Time 4.603 (4.603)	Data Time 4.068 (4.068)	Loss 2.0566 (2.0566)
# Epoch: [92][200/273]	Batch Time 1.067 (1.145)	Data Time 0.489 (0.595)	Loss 2.3784 (2.1473)
# Epoch: [93][0/273]	Batch Time 5.328 (5.328)	Data Time 4.800 (4.800)	Loss 2.1540 (2.1540)
# Epoch: [93][200/273]	Batch Time 0.546 (1.144)	Data Time 0.000 (0.593)	Loss 2.3414 (2.1540)
# Epoch: [94][0/273]	Batch Time 4.665 (4.665)	Data Time 4.025 (4.025)	Loss 2.2504 (2.2504)
# Epoch: [94][200/273]	Batch Time 0.576 (1.158)	Data Time 0.001 (0.609)	Loss 1.8428 (2.1586)
# Epoch: [95][0/273]	Batch Time 4.770 (4.770)	Data Time 4.187 (4.187)	Loss 2.1893 (2.1893)
# Epoch: [95][200/273]	Batch Time 3.007 (1.160)	Data Time 2.443 (0.608)	Loss 2.1950 (2.1381)
# Epoch: [96][0/273]	Batch Time 4.690 (4.690)	Data Time 4.092 (4.092)	Loss 1.9092 (1.9092)
# Epoch: [96][200/273]	Batch Time 3.000 (1.168)	Data Time 2.477 (0.615)	Loss 2.2135 (2.1558)
# Epoch: [97][0/273]	Batch Time 4.446 (4.446)	Data Time 3.881 (3.881)	Loss 2.3496 (2.3496)
# Epoch: [97][200/273]	Batch Time 1.642 (1.158)	Data Time 1.083 (0.608)	Loss 2.2529 (2.1609)
# Epoch: [98][0/273]	Batch Time 5.362 (5.362)	Data Time 4.796 (4.796)	Loss 2.3340 (2.3340)
# Epoch: [98][200/273]	Batch Time 0.591 (1.149)	Data Time 0.001 (0.598)	Loss 1.9762 (2.1258)
# Epoch: [99][0/273]	Batch Time 5.143 (5.143)	Data Time 4.579 (4.579)	Loss 2.0034 (2.0034)
# Epoch: [99][200/273]	Batch Time 0.557 (1.145)	Data Time 0.000 (0.600)	Loss 2.0902 (2.1609)

# %%
# !python detect.py
# Out:
# Loaded checkpoint from epoch 100.
#
# 1it [00:02,  2.42s/it]/content/drive/MyDrive/Colab Notebooks/URP/kaist_pd_urp/model.py:501: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:27.)
#   image_boxes.append(class_decoded_locs[1 - suppress])
# /content/drive/MyDrive/Colab Notebooks/URP/kaist_pd_urp/model.py:503: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:27.)
#   image_scores.append(class_scores[1 - suppress])
# 2252it [10:41,  3.51it/s]

# %%
# !python Evaluation_official.py
# Out:
# loading annotations into memory...
# Done (t=0.23s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.21s).
# Accumulating evaluation results...
# DONE (t=0.00s).
#  Average Miss Rate  (MR) @ Reasonable         [ IoU=0.50      | height=[55:10000000000] | visibility=[none+partial_occ] ] = 38.32%
# Recall: 0.7597684515195369

# %%
# !python moving_image.py
# Out:
# Loaded checkpoint from epoch 100.
#
# 1it [00:01,  1.04s/it]/content/drive/MyDrive/Colab Notebooks/URP/kaist_pd_urp/model.py:501: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:27.)
#   image_boxes.append(class_decoded_locs[1 - suppress])
# /content/drive/MyDrive/Colab Notebooks/URP/kaist_pd_urp/model.py:503: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:27.)
#   image_scores.append(class_scores[1 - suppress])
# 2252it [01:11, 31.68it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
