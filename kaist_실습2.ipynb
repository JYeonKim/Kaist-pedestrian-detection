# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 현재경로 설정
# !cd "/content/drive/My Drive/Colab Notebooks/URP/kaist_pd_urp"

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/URP/kaist_pd_urp')

# %%
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/URP/kaist_pd_urp

# %%
# !git clone https://github.com/sgrvinod/a-PyTorch-Tutorial-to-Object-Detection.git
# Out:
# Cloning into 'a-PyTorch-Tutorial-to-Object-Detection'...
# remote: Enumerating objects: 249, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 249 (delta 60), reused 57 (delta 57), pack-reused 181
# Receiving objects: 100% (249/249), 175.95 MiB | 13.83 MiB/s, done.
# Resolving deltas: 100% (118/118), done.
# Checking out files: 100% (62/62), done.

# %%
# !python train.py
# Out:
# Loaded checkpoint from epoch 36.
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# Epoch: [36][0/273]	Batch Time 55.251 (55.251)	Data Time 42.237 (42.237)	Loss 2.2996 (2.2996)
# Epoch: [36][200/273]	Batch Time 13.221 (4.151)	Data Time 12.674 (3.554)	Loss 2.2738 (2.5250)
# Epoch: [37][0/273]	Batch Time 5.887 (5.887)	Data Time 5.244 (5.244)	Loss 2.4873 (2.4873)
# Epoch: [37][200/273]	Batch Time 0.557 (1.400)	Data Time 0.001 (0.825)	Loss 2.2937 (2.5458)
# Epoch: [38][0/273]	Batch Time 6.317 (6.317)	Data Time 5.744 (5.744)	Loss 2.3016 (2.3016)
# Epoch: [38][200/273]	Batch Time 0.576 (1.399)	Data Time 0.001 (0.820)	Loss 2.6954 (2.5440)
# Epoch: [39][0/273]	Batch Time 5.425 (5.425)	Data Time 4.809 (4.809)	Loss 2.1676 (2.1676)
# Epoch: [39][200/273]	Batch Time 0.821 (1.402)	Data Time 0.252 (0.822)	Loss 2.6649 (2.5365)
# Epoch: [40][0/273]	Batch Time 5.813 (5.813)	Data Time 5.174 (5.174)	Loss 2.6569 (2.6569)
# Epoch: [40][200/273]	Batch Time 0.637 (1.402)	Data Time 0.076 (0.826)	Loss 2.5590 (2.4999)
# Epoch: [41][0/273]	Batch Time 6.793 (6.793)	Data Time 6.154 (6.154)	Loss 3.1057 (3.1057)
# Epoch: [41][200/273]	Batch Time 0.579 (1.425)	Data Time 0.001 (0.844)	Loss 2.1834 (2.4950)
# Epoch: [42][0/273]	Batch Time 5.397 (5.397)	Data Time 4.775 (4.775)	Loss 2.2422 (2.2422)
# Epoch: [42][200/273]	Batch Time 0.838 (1.416)	Data Time 0.285 (0.840)	Loss 2.3962 (2.4867)
# Epoch: [43][0/273]	Batch Time 6.324 (6.324)	Data Time 5.734 (5.734)	Loss 2.4184 (2.4184)
# Epoch: [43][200/273]	Batch Time 0.561 (1.421)	Data Time 0.001 (0.842)	Loss 2.3976 (2.4785)
# Epoch: [44][0/273]	Batch Time 6.140 (6.140)	Data Time 5.483 (5.483)	Loss 2.4730 (2.4730)
# Epoch: [44][200/273]	Batch Time 2.554 (1.412)	Data Time 1.978 (0.831)	Loss 2.4847 (2.5067)
# Epoch: [45][0/273]	Batch Time 6.906 (6.906)	Data Time 6.347 (6.347)	Loss 2.7310 (2.7310)
# Epoch: [45][200/273]	Batch Time 1.714 (1.417)	Data Time 1.169 (0.841)	Loss 2.8648 (2.4472)
# Epoch: [46][0/273]	Batch Time 6.047 (6.047)	Data Time 5.474 (5.474)	Loss 2.4626 (2.4626)
# Epoch: [46][200/273]	Batch Time 0.577 (1.415)	Data Time 0.001 (0.837)	Loss 2.6698 (2.4453)
# Epoch: [47][0/273]	Batch Time 6.503 (6.503)	Data Time 5.933 (5.933)	Loss 2.5348 (2.5348)
# Epoch: [47][200/273]	Batch Time 4.003 (1.443)	Data Time 3.442 (0.866)	Loss 2.4647 (2.4365)
# Epoch: [48][0/273]	Batch Time 6.351 (6.351)	Data Time 5.787 (5.787)	Loss 2.3904 (2.3904)
# Epoch: [48][200/273]	Batch Time 3.567 (1.447)	Data Time 2.986 (0.870)	Loss 2.3038 (2.4376)
# Epoch: [49][0/273]	Batch Time 7.171 (7.171)	Data Time 6.545 (6.545)	Loss 2.0719 (2.0719)
# Epoch: [49][200/273]	Batch Time 3.325 (1.475)	Data Time 2.738 (0.898)	Loss 2.4717 (2.4358)
# Epoch: [50][0/273]	Batch Time 5.677 (5.677)	Data Time 5.075 (5.075)	Loss 1.9659 (1.9659)
# Epoch: [50][200/273]	Batch Time 0.606 (1.427)	Data Time 0.056 (0.847)	Loss 2.4853 (2.4125)
# Epoch: [51][0/273]	Batch Time 5.690 (5.690)	Data Time 5.121 (5.121)	Loss 2.4988 (2.4988)
# Epoch: [51][200/273]	Batch Time 3.618 (1.440)	Data Time 3.020 (0.857)	Loss 2.6929 (2.4425)
# Epoch: [52][0/273]	Batch Time 5.991 (5.991)	Data Time 5.333 (5.333)	Loss 2.4133 (2.4133)
# Epoch: [52][200/273]	Batch Time 5.300 (1.455)	Data Time 4.722 (0.875)	Loss 2.8447 (2.4157)
# Epoch: [53][0/273]	Batch Time 6.424 (6.424)	Data Time 5.775 (5.775)	Loss 2.2201 (2.2201)
# Epoch: [53][200/273]	Batch Time 3.658 (1.450)	Data Time 3.087 (0.868)	Loss 2.9528 (2.3936)
# Epoch: [54][0/273]	Batch Time 6.874 (6.874)	Data Time 6.209 (6.209)	Loss 2.5252 (2.5252)
# Epoch: [54][200/273]	Batch Time 2.141 (1.453)	Data Time 1.563 (0.872)	Loss 2.6835 (2.4079)
# Epoch: [55][0/273]	Batch Time 7.080 (7.080)	Data Time 6.492 (6.492)	Loss 2.5004 (2.5004)
# Epoch: [55][200/273]	Batch Time 3.822 (1.459)	Data Time 3.264 (0.878)	Loss 2.4700 (2.4050)
# Epoch: [56][0/273]	Batch Time 5.442 (5.442)	Data Time 4.868 (4.868)	Loss 2.7884 (2.7884)
# Epoch: [56][200/273]	Batch Time 0.580 (1.455)	Data Time 0.017 (0.873)	Loss 2.5370 (2.4298)
# Epoch: [57][0/273]	Batch Time 6.154 (6.154)	Data Time 5.578 (5.578)	Loss 2.1700 (2.1700)
# Epoch: [57][200/273]	Batch Time 0.607 (1.448)	Data Time 0.001 (0.867)	Loss 2.4269 (2.4085)
# Epoch: [58][0/273]	Batch Time 6.111 (6.111)	Data Time 5.460 (5.460)	Loss 2.3900 (2.3900)
# Epoch: [58][200/273]	Batch Time 2.078 (1.451)	Data Time 1.452 (0.872)	Loss 2.4921 (2.3994)
# Epoch: [59][0/273]	Batch Time 6.890 (6.890)	Data Time 6.275 (6.275)	Loss 2.4487 (2.4487)
# Epoch: [59][200/273]	Batch Time 0.582 (1.455)	Data Time 0.001 (0.874)	Loss 2.2134 (2.3761)
# Epoch: [60][0/273]	Batch Time 7.373 (7.373)	Data Time 6.776 (6.776)	Loss 2.0884 (2.0884)
# Epoch: [60][200/273]	Batch Time 5.009 (1.447)	Data Time 4.392 (0.866)	Loss 2.3714 (2.3692)
# Epoch: [61][0/273]	Batch Time 6.645 (6.645)	Data Time 6.044 (6.044)	Loss 2.6461 (2.6461)
# Epoch: [61][200/273]	Batch Time 3.297 (1.421)	Data Time 2.657 (0.840)	Loss 2.4971 (2.3649)
# Epoch: [62][0/273]	Batch Time 6.066 (6.066)	Data Time 5.466 (5.466)	Loss 2.1943 (2.1943)
# Epoch: [62][200/273]	Batch Time 2.017 (1.415)	Data Time 1.400 (0.837)	Loss 2.3319 (2.3323)
# Epoch: [63][0/273]	Batch Time 5.247 (5.247)	Data Time 4.663 (4.663)	Loss 2.6421 (2.6421)
# Epoch: [63][200/273]	Batch Time 0.635 (1.427)	Data Time 0.001 (0.848)	Loss 2.3093 (2.3678)
# Epoch: [64][0/273]	Batch Time 5.549 (5.549)	Data Time 4.959 (4.959)	Loss 1.9164 (1.9164)
# Epoch: [64][200/273]	Batch Time 2.936 (1.416)	Data Time 2.372 (0.838)	Loss 2.0392 (2.3209)
# Epoch: [65][0/273]	Batch Time 6.517 (6.517)	Data Time 5.908 (5.908)	Loss 2.7441 (2.7441)
# Epoch: [65][200/273]	Batch Time 1.312 (1.430)	Data Time 0.725 (0.852)	Loss 1.9350 (2.3382)
# Epoch: [66][0/273]	Batch Time 6.222 (6.222)	Data Time 5.600 (5.600)	Loss 2.4339 (2.4339)
# Epoch: [66][200/273]	Batch Time 3.007 (1.429)	Data Time 2.432 (0.854)	Loss 2.3087 (2.3374)
# Epoch: [67][0/273]	Batch Time 6.892 (6.892)	Data Time 6.326 (6.326)	Loss 2.8275 (2.8275)
# Epoch: [67][200/273]	Batch Time 0.571 (1.436)	Data Time 0.001 (0.858)	Loss 2.1340 (2.3381)
# Epoch: [68][0/273]	Batch Time 6.066 (6.066)	Data Time 5.509 (5.509)	Loss 2.5756 (2.5756)
# Epoch: [68][200/273]	Batch Time 0.559 (1.442)	Data Time 0.001 (0.865)	Loss 1.9815 (2.3289)
# Epoch: [69][0/273]	Batch Time 6.177 (6.177)	Data Time 5.568 (5.568)	Loss 1.9277 (1.9277)
# Epoch: [69][200/273]	Batch Time 3.560 (1.466)	Data Time 2.984 (0.882)	Loss 2.7311 (2.3107)
# 출력
# DECAYING learning rate.
#  The new LR is 0.000050
#
# Epoch: [70][0/273]	Batch Time 6.040 (6.040)	Data Time 5.439 (5.439)	Loss 2.6121 (2.6121)
# Epoch: [70][200/273]	Batch Time 0.575 (1.428)	Data Time 0.001 (0.845)	Loss 2.0131 (2.2355)
# Epoch: [71][0/273]	Batch Time 6.389 (6.389)	Data Time 5.797 (5.797)	Loss 2.1721 (2.1721)
# Epoch: [71][200/273]	Batch Time 3.637 (1.472)	Data Time 3.077 (0.889)	Loss 1.9509 (2.2221)
# Epoch: [72][0/273]	Batch Time 5.569 (5.569)	Data Time 5.002 (5.002)	Loss 2.4779 (2.4779)
# Epoch: [72][200/273]	Batch Time 0.605 (1.464)	Data Time 0.001 (0.884)	Loss 2.2864 (2.2134)
# Epoch: [73][0/273]	Batch Time 6.572 (6.572)	Data Time 6.006 (6.006)	Loss 2.1353 (2.1353)
# Epoch: [73][200/273]	Batch Time 2.401 (1.450)	Data Time 1.752 (0.869)	Loss 2.2331 (2.2017)
# Epoch: [74][0/273]	Batch Time 5.569 (5.569)	Data Time 5.000 (5.000)	Loss 2.0239 (2.0239)
# Epoch: [74][200/273]	Batch Time 0.565 (1.454)	Data Time 0.000 (0.875)	Loss 2.0648 (2.2009)
# Epoch: [75][0/273]	Batch Time 6.629 (6.629)	Data Time 6.041 (6.041)	Loss 2.2002 (2.2002)
# Epoch: [75][200/273]	Batch Time 0.572 (1.477)	Data Time 0.011 (0.899)	Loss 2.5992 (2.2211)
# Epoch: [76][0/273]	Batch Time 5.852 (5.852)	Data Time 5.278 (5.278)	Loss 2.2738 (2.2738)
# Epoch: [76][200/273]	Batch Time 3.396 (1.494)	Data Time 2.824 (0.915)	Loss 1.9104 (2.2027)
# Epoch: [77][0/273]	Batch Time 5.707 (5.707)	Data Time 5.054 (5.054)	Loss 2.3351 (2.3351)
# Epoch: [77][200/273]	Batch Time 3.672 (1.482)	Data Time 3.091 (0.903)	Loss 2.4767 (2.2097)
# Epoch: [78][0/273]	Batch Time 7.440 (7.440)	Data Time 6.864 (6.864)	Loss 2.0802 (2.0802)
# Epoch: [78][200/273]	Batch Time 0.559 (1.488)	Data Time 0.001 (0.906)	Loss 2.4106 (2.2378)
# Epoch: [79][0/273]	Batch Time 5.377 (5.377)	Data Time 4.797 (4.797)	Loss 1.9878 (1.9878)
# Epoch: [79][200/273]	Batch Time 2.975 (1.469)	Data Time 2.417 (0.889)	Loss 2.1530 (2.1850)

# %%
# !python detect.py
# Out:
# Loaded checkpoint from epoch 80.
#
# 1it [00:01,  1.10s/it]/content/drive/MyDrive/Colab Notebooks/URP/kaist_pd_urp/model.py:501: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:27.)
#   image_boxes.append(class_decoded_locs[1 - suppress])
# /content/drive/MyDrive/Colab Notebooks/URP/kaist_pd_urp/model.py:503: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:27.)
#   image_scores.append(class_scores[1 - suppress])
# 2252it [16:02,  2.34it/s]

# %%
# !python Evaluation_official.py
# Out:
# loading annotations into memory...
# Done (t=0.37s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.29s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Miss Rate  (MR) @ Reasonable         [ IoU=0.50      | height=[55:10000000000] | visibility=[none+partial_occ] ] = 37.89%
# Recall: 0.779869659666908

# %%
# !python moving_image.py
# Out:
# Loaded checkpoint from epoch 80.
#
# 1it [00:01,  1.14s/it]/content/drive/MyDrive/Colab Notebooks/URP/kaist_pd_urp/model.py:501: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:27.)
#   image_boxes.append(class_decoded_locs[1 - suppress])
# /content/drive/MyDrive/Colab Notebooks/URP/kaist_pd_urp/model.py:503: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:27.)
#   image_scores.append(class_scores[1 - suppress])
# 2252it [01:18, 28.86it/s]
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
